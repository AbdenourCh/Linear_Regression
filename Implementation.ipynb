# %% [markdown]
# # Implementation of Linear Regression Algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %run Linear_Regression.py

# %% [markdown]
# Open data from text file

# %%
data = np.array([[float(i) for i in line.split(',')] for line in open("data.txt")])
X=data[:,0]
Y=data[:,1]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=X,y=Y,marker="X",s=50)
plt.ylabel('Profit in $10,000')
plt.xlabel('Population of City in 10,000s')
# Out:
# Text(0.5, 0, 'Population of City in 10,000s')

# %% [markdown]
# Create linear_regression object

# %%
#Learning_rate 0.01 and # of iterations 400
lr = linear_regression(0.01,400)

# %%
#reshape X and Y as vector 
X = X.reshape(len(X),1)
Y = Y.reshape(len(Y),1)
#normalize features in X
X = lr.feature_normalize(X)
#add ones columns in X
X = np.c_[np.ones(X.shape[0]),X]

# %%
#Run gradient descent algorithm
theta,cost = lr.gradient_descent(X,Y)

# %% [markdown]
# Visualization of the result

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.scatterplot(x=X[:,1].flatten(),y=Y.flatten(),marker="X",s=50,ax = ax)
sns.lineplot(x=X[:,1].flatten(),y=X.dot(theta).flatten())
plt.ylabel('Profit in $10,000')
plt.xlabel('Population of City in 10,000s')
# Out:
# Text(0.5, 0, 'Population of City in 10,000s')

# %%
plt.subplots(figsize=(10,6))
sns.lineplot(data=np.array(cost))
plt.ylabel('Cost')
plt.xlabel('# of iterations')
# Out:
# Text(0.5, 0, '# of iterations')
